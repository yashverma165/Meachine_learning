# %% [markdown]
# <a href="https://colab.research.google.com/github/yashverma165/Meachine_learning/blob/main/SVM_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SVM Regression implementaion

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.datasets import make_regression
x,y=make_regression(n_samples= 1000,n_features=2,n_targets=1,noise=3.0)
x
# Out:
# array([[-1.19950923, -0.71953909],
#        [-1.21120477,  0.6574535 ],
#        [ 0.36286371,  0.05805181],
#        ...,
#        [-1.30510341,  1.84797377],
#        [ 1.58245716,  0.69625127],
#        [ 1.70132353,  0.45142618]])

# %%
y
# Out:
# array([-3.87890957e+01, -1.58941561e+01,  2.69186012e+00, -3.53730569e+00,
#         5.42686469e+01, -9.67578494e+00, -2.31017860e+01,  5.13052647e+01,
#         3.89456807e+00, -1.66084343e+01, -3.20305834e+01, -1.05768326e+01,
#         1.51277935e+01,  2.18649309e+01,  3.12122657e+00, -8.29333426e+00,
#         1.21106708e+01,  1.19341397e+01, -1.41254245e+01,  1.12636160e+01,
#        -1.99066326e+01,  8.50386407e+00, -9.80691049e+00,  3.78717552e+00,
#        -1.83590717e+01,  5.13888227e+01,  4.89547158e+01,  2.95752938e+01,
#         2.03025457e-01, -1.20243334e+01, -4.64947381e+01,  1.50975818e+01,
#         1.68292806e+01,  3.60978196e+01, -7.78473016e+00, -4.43644636e+01,
#        -3.10011014e+01,  2.16348621e+01, -1.14261684e+01,  1.05520472e+01,
#         2.92043443e+01, -4.51053799e-01, -2.72442887e+01,  2.37221078e-01,
#         2.90950806e+01, -9.94326436e+00, -2.14088461e+01,  1.38467892e+01,
# ...

# %%
sns.scatterplot(x=pd.DataFrame(x)[0],y=pd.DataFrame(x)[1],hue=y)
# Out:
# <Axes: xlabel='0', ylabel='1'>

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=10,test_size=0.25)

# %%
from sklearn.svm import SVR
svr=SVR(kernel='linear')

# %%
svr.fit(x_train,y_train)
# Out:
# SVR(kernel='linear')

# %%
svr.coef_
# Out:
# array([[18.32139938, 19.49989951]])

# %%
y_pred=svr.predict(x_test)
y_pred
# Out:
# array([-14.42803554,  35.60284411,  -6.50162061,  12.35420023,
#        -43.40071232,  27.53845755, -23.92114009,   1.38155071,
#         -5.54365109, -10.11745104,   8.63883644,  21.95546041,
#         38.88006206,  37.54734278,  42.93768954, -34.77894961,
#         -4.06046679, -49.91132726,  33.18297918, -30.27514939,
#        -59.68664953,  12.50583497, -13.71336333, -23.97260837,
#         23.89903278,   7.56816694,   0.75783124,  -9.9693757 ,
#        -21.32349833,  21.21512459, -26.61796276,  26.35807528,
#          5.3796138 ,  40.36145478,   6.03991008,  12.46112612,
#         37.46025373,   0.63505148, -20.01958348,   6.15434291,
#        -29.33940965, -11.03326473,  -3.43412632,  -5.14800256,
#         38.96839763, -39.35380571, -19.3892254 , -46.34203821,
#        -48.22618987, -26.60219271,  31.78084304,  60.26430053,
#        -32.0732164 ,  39.6083738 ,  14.87375801,   5.75719796,
#         26.22128887, -20.05538511,  -6.49977766,  -8.09964541,
# ...

# %%
from sklearn.metrics import r2_score
print(r2_score(y_pred,y_test))
# Out:
# 0.9852773508422739

# %% [markdown]
# ## Hyperparmeter Tuning in SVM Regression

# %%
from sklearn.model_selection import GridSearchCV
para={'C':[1,10,100],
      'gamma':[1,0.1,.01,.001],
      'kernel':['linear']}

# %%
grid=GridSearchCV(SVR(),param_grid=para,cv=5,verbose=3,refit=True)

# %%
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 1/5] END .......C=1, gamma=1, kernel=linear;, score=0.990 total time=   0.1s
# [CV 2/5] END .......C=1, gamma=1, kernel=linear;, score=0.991 total time=   0.1s
# [CV 3/5] END .......C=1, gamma=1, kernel=linear;, score=0.987 total time=   0.1s
# [CV 4/5] END .......C=1, gamma=1, kernel=linear;, score=0.988 total time=   0.1s
# [CV 5/5] END .......C=1, gamma=1, kernel=linear;, score=0.985 total time=   0.1s
# [CV 1/5] END .....C=1, gamma=0.1, kernel=linear;, score=0.990 total time=   0.0s
# [CV 2/5] END .....C=1, gamma=0.1, kernel=linear;, score=0.991 total time=   0.0s
# [CV 3/5] END .....C=1, gamma=0.1, kernel=linear;, score=0.987 total time=   0.1s
# [CV 4/5] END .....C=1, gamma=0.1, kernel=linear;, score=0.988 total time=   0.1s
# [CV 5/5] END .....C=1, gamma=0.1, kernel=linear;, score=0.985 total time=   0.1s
# [CV 1/5] END ....C=1, gamma=0.01, kernel=linear;, score=0.990 total time=   0.1s
# ...

# %%
grid.best_params_
# Out:
# {'C': 100, 'gamma': 1, 'kernel': 'linear'}

# %%
y_pred=grid.predict(x_test)
print(r2_score(y_pred,y_test))
# Out:
# 0.9853204047777729
